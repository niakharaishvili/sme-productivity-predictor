# %% [markdown]
# # 02 — Preprocessing & Feature Engineering
# Clean data and prepare features for modelling.

# %%
import sys
sys.path.append('..')

from src.data_loader import generate_synthetic_data, save_processed
from src.features import encode_categoricals, engineer_features, get_feature_matrix

df = generate_synthetic_data()
print('Raw shape:', df.shape)
df.head()

# %%
# Engineer features
df_feat = engineer_features(df)
print('New features added:')
print([c for c in df_feat.columns if c not in df.columns])

# %%
# Get model-ready matrices
X, y = get_feature_matrix(df_feat)
print('X shape:', X.shape)
print('y distribution:\n', y.value_counts())
X.head()

# %%
# Save processed data
save_processed(df_feat, 'sme_processed.csv')
print('Done.')

# %% [markdown]
# **Features going into the model:**

# %%
print(list(X.columns))
